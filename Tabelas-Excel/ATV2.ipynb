# %%
import pandas as pd

# Dados organizados do Balanço Patrimonial (BP)
bp_data = {
    'Grupo': [
        'Ativo Circulante', 'Ativo Circulante', 'Ativo Circulante', 'Ativo Circulante', 
        'Ativo Circulante', 'Ativo Circulante', 'Ativo Circulante', 'Ativo Circulante', 
        'Ativo Não Circulante', 'Ativo Não Circulante', 'Ativo Não Circulante', 
        'Ativo Não Circulante', 'Ativo Não Circulante', 'Ativo Não Circulante', 
        'Passivo Circulante', 'Passivo Circulante', 'Passivo Circulante', 
        'Passivo Não Circulante', 'Passivo Não Circulante', 'Patrimônio Líquido'
    ],
    'Contas': [
        'Salários e encargos', 'Impostos, taxas e contribuições a recolher', 'Aplicações financeiras (Curto Prazo)', 
        'Investimentos', 'Estoques', 'Contas a receber', 'Tributos a recuperar', 'Veículos',
        'Imobilizado', 'Aplicações financeiras (Longo Prazo)', 'Instrumentos financeiros derivativos (Longo Prazo)',
        'Provisões (Longo Prazo)', 'Benefícios a funcionários (Longo Prazo)', 'Outros ativos (Longo Prazo)',
        'Contas a pagar (Curto Prazo)', 'Empréstimos e financiamentos (Curto Prazo)', 'Provisões (Curto Prazo)',
        'Empréstimos e financiamentos (Longo Prazo)', 'Instrumentos financeiros derivativos (Longo Prazo)',
        'Capital social'
    ],
    'Valores': [
        2128.55, 513.32, 277.20, 289.06, 9619.02, 5741.50, 3435.69, 7969.59, 26630.16, 242.17, 
        11.64, 559.61, 2011.80, 38003.64, 23195.10, 1298.09, 418.40, 2202.98, 1054.34, 58177.99
    ]
}

# Dados do Demonstrativo de Fluxo de Caixa (DFC)
dfc_data = {
    'Atividades': [
        'Geração de caixa das atividades operacionais', '(Aumento)/redução no contas a receber e demais contas a receber',
        '(Aumento)/redução nos estoques', '(Aumento)/(redução) no contas a pagar e demais contas a pagar', 
        'Juros pagos', 'Juros recebidos', 'Imposto de renda e contribuição social (pagos)/creditados',
        'Proventos/(recompra) de ações', 'Aquisição de participação de não controladores', 'Proventos de empréstimos', 
        'Liquidação de empréstimos', 'Caixa líquido de custos financeiros, exceto juros', 'Pagamento de passivos de arrendamento', 
        'Dividendos e juros sobre o capital próprio pagos', 'Proventos da venda de imobilizado e intangíveis', 
        'Aquisição de imobilizado e intangíveis', 'Aplicação financeira/proventos líquidos de títulos de dívida', 
        'Proventos/(aquisição) de outros ativos, líquidos'
    ],
    'Ano 1': [
        3845.23, 370.76, 357.86, 1308.55, 126.93, 361.85, 726.74, 291.10, 2.93, 20.35, 444.54, 547.68, 346.08, 
        85.96, 54.75, 1028.09, 0.00, 109.55
    ],
    'Ano 2': [
        3807.73, 47.95, 333.85, 1793.42, 147.20, 208.54, 453.69, 20.23, 7.09, 0.00, 54.76, 1211.27, 284.61, 
        128.61, 34.45, 1295.74, 1.90, 44.83
    ]
}

# Criando DataFrames para cada tabela
bp_df = pd.DataFrame(bp_data)
dfc_df = pd.DataFrame(dfc_data)

# Criando um writer para salvar várias abas no mesmo arquivo Excel
with pd.ExcelWriter('balanco_e_fluxo_de_caixa_organizado.xlsx', engine='xlsxwriter') as writer:
    # Escrever cada DataFrame em uma aba específica
    bp_df.to_excel(writer, sheet_name='Balanço Patrimonial', index=False)
    dfc_df.to_excel(writer, sheet_name='Fluxo de Caixa', index=False)

print("Arquivo Excel com Balanço Patrimonial e Fluxo de Caixa organizado foi gerado com sucesso.")
# Out:
# Arquivo Excel com Balanço Patrimonial e Fluxo de Caixa organizado foi gerado com sucesso.

# %%
import pandas as pd

# Dados organizados do Balanço Patrimonial (BP)
bp_data = {
    'Grupo': [
        'Ativo Circulante', 'Ativo Circulante', 'Ativo Circulante', 'Ativo Circulante', 
        'Ativo Circulante', 'Ativo Circulante', 'Ativo Circulante', 'Ativo Circulante', 
        'Ativo Não Circulante', 'Ativo Não Circulante', 'Ativo Não Circulante', 
        'Ativo Não Circulante', 'Ativo Não Circulante', 'Ativo Não Circulante', 
        'Passivo Circulante', 'Passivo Circulante', 'Passivo Circulante', 
        'Passivo Não Circulante', 'Passivo Não Circulante', 'Patrimônio Líquido'
    ],
    'Contas': [
        'Salários e encargos', 'Impostos, taxas e contribuições a recolher', 'Aplicações financeiras (Curto Prazo)', 
        'Investimentos', 'Estoques', 'Contas a receber', 'Tributos a recuperar', 'Veículos',
        'Imobilizado', 'Aplicações financeiras (Longo Prazo)', 'Instrumentos financeiros derivativos (Longo Prazo)',
        'Provisões (Longo Prazo)', 'Benefícios a funcionários (Longo Prazo)', 'Outros ativos (Longo Prazo)',
        'Contas a pagar (Curto Prazo)', 'Empréstimos e financiamentos (Curto Prazo)', 'Provisões (Curto Prazo)',
        'Empréstimos e financiamentos (Longo Prazo)', 'Instrumentos financeiros derivativos (Longo Prazo)',
        'Capital social'
    ],
    'Valores': [
        2128.55, 513.32, 277.20, 289.06, 9619.02, 5741.50, 3435.69, 7969.59, 26630.16, 242.17, 
        11.64, 559.61, 2011.80, 38003.64, 23195.10, 1298.09, 418.40, 2202.98, 1054.34, 58177.99
    ]
}

# Dados do Demonstrativo de Fluxo de Caixa (DFC)
dfc_data = {
    'Atividades': [
        'Geração de caixa das atividades operacionais', '(Aumento)/redução no contas a receber e demais contas a receber',
        '(Aumento)/redução nos estoques', '(Aumento)/(redução) no contas a pagar e demais contas a pagar', 
        'Juros pagos', 'Juros recebidos', 'Imposto de renda e contribuição social (pagos)/creditados',
        'Proventos/(recompra) de ações', 'Aquisição de participação de não controladores', 'Proventos de empréstimos', 
        'Liquidação de empréstimos', 'Caixa líquido de custos financeiros, exceto juros', 'Pagamento de passivos de arrendamento', 
        'Dividendos e juros sobre o capital próprio pagos', 'Proventos da venda de imobilizado e intangíveis', 
        'Aquisição de imobilizado e intangíveis', 'Aplicação financeira/proventos líquidos de títulos de dívida', 
        'Proventos/(aquisição) de outros ativos, líquidos'
    ],
    'Ano 1': [
        3845.23, 370.76, 357.86, 1308.55, 126.93, 361.85, 726.74, 291.10, 2.93, 20.35, 444.54, 547.68, 346.08, 
        85.96, 54.75, 1028.09, 0.00, 109.55
    ],
    'Ano 2': [
        3807.73, 47.95, 333.85, 1793.42, 147.20, 208.54, 453.69, 20.23, 7.09, 0.00, 54.76, 1211.27, 284.61, 
        128.61, 34.45, 1295.74, 1.90, 44.83
    ]
}

# Dados simulados para a DRE
dre_data = {
    'Contas': [
        'Receita de Serviços Prestados', 'Receita de Produtos', 'Deduções da Receita Bruta', 
        'Devoluções', 'Imposto Simples Nacional', 'Receita Operacional Líquida', 
        'Custos dos Produtos Vendidos', 'Custo dos Serviços Prestados', 'Resultado Operacional Bruto', 
        'Despesas Operacionais', 'Aluguel', 'Energia', 'Internet', 'Mão-de-Obra', 'Marketing', 
        'Encargos Sociais', 'Despesas Financeiras', 'Resultado Operacional Líquido', 
        'Margem de Lucro Operacional %', 'Lucro ou Prejuízo Líquido do Exercício'
    ],
    'Mês 1': [
        50000, 15000, 5000, 2000, 3500, '=B2+B3-B4-B5-B6', 
        12000, 8000, '=B7-B8-B9', 14000, 3000, 1200, 800, 5000, 2000, 1800, 500, 
        '=B10-B11-B12-B13-B14-B15-B16', '=B17/B7*100', '=B17'
    ],
    'Mês 2': [
        52000, 15500, 5100, 2100, 3600, '=C2+C3-C4-C5-C6', 
        12500, 8500, '=C7-C8-C9', 15000, 3100, 1250, 850, 5200, 2200, 1850, 550, 
        '=C10-C11-C12-C13-C14-C15-C16', '=C17/C7*100', '=C17'
    ],
    'Mês 3': [
        54000, 16000, 5200, 2200, 3700, '=D2+D3-D4-D5-D6', 
        13000, 9000, '=D7-D8-D9', 16000, 3200, 1300, 900, 5400, 2400, 1900, 600, 
        '=D10-D11-D12-D13-D14-D15-D16', '=D17/D7*100', '=D17'
    ]
}

# Criando DataFrames para cada tabela
bp_df = pd.DataFrame(bp_data)
dfc_df = pd.DataFrame(dfc_data)
dre_df = pd.DataFrame(dre_data)

# Criando um writer para salvar várias abas no mesmo arquivo Excel
with pd.ExcelWriter('balanco_fluxo_DRE_organizado.xlsx', engine='xlsxwriter') as writer:
    # Escrever o Balanço Patrimonial
    bp_df.to_excel(writer, sheet_name='Balanço Patrimonial', index=False)
    
    # Escrever o Fluxo de Caixa
    dfc_df.to_excel(writer, sheet_name='Fluxo de Caixa', index=False)
    
    # Escrever a DRE
    dre_df.to_excel(writer, sheet_name='DRE', index=False)
    
    # Definir as fórmulas e formatar o Excel com xlsxwriter
    workbook  = writer.book
    worksheet = writer.sheets['DRE']
    
    # Aplicar formatação condicional e ajustes na aba da DRE
    format_bold = workbook.add_format({'bold': True})
    
    # Aplicando negrito nas linhas de totalizadores e margens
    worksheet.write('A6', 'Receita Operacional Líquida', format_bold)
    worksheet.write('A9', 'Resultado Operacional Bruto', format_bold)
    worksheet.write('A18', 'Resultado Operacional Líquido', format_bold)
    worksheet.write('A19', 'Margem de Lucro Operacional %', format_bold)
    worksheet.write('A20', 'Lucro ou Prejuízo Líquido do Exercício', format_bold)

print("Arquivo Excel com Balanço Patrimonial, Fluxo de Caixa e DRE foi gerado com sucesso.")
# Out:
# Arquivo Excel com Balanço Patrimonial, Fluxo de Caixa e DRE foi gerado com sucesso.

# %%
import pandas as pd

# Dados das tabelas
# Receita Mensal
receitas = {
    'Fonte': ['Salário', 'Freelancer', 'Vendas Online', 'Renda de Investimentos'],
    'Valor (R$)': [2500.00, 800.00, 300.00, 150.00]
}

# Despesas Fixas Mensais
despesas_fixas = {
    'Categoria': ['Aluguel', 'Energia Elétrica', 'Internet', 'Transporte', 'Alimentação', 
                  'Academia', 'Plano de Saúde', 'Faculdade', 'Assinatura de Streaming (filmes/séries)',
                  'Streaming de Músicas', 'Cursos Online'],
    'Valor (R$)': [800.00, 120.00, 90.00, 150.00, 600.00, 
                   80.00, 300.00, 600.00, 30.00, 
                   20.00, 200.00]
}

# Despesas Variáveis Mensais
despesas_variaveis = {
    'Categoria': ['Lazer', 'Compras Online', 'Restaurante', 'Emergências', 'Outros', 'Jogos de Videogame'],
    'Valor (R$)': [150.00, 100.00, 120.00, 50.00, 80.00, 50.00]
}

# Resumo Mensal
resumo_mensal = {
    'Tipo': ['Receita Total', 'Despesas Fixas', 'Despesas Variáveis', 'Saldo Mensal'],
    'Valor (R$)': [3750.00, 2990.00, 550.00, 210.00]
}

# Investimentos Mensais Sugeridos
investimentos = {
    'Investimento': ['Reserva de Emergência', 'Investimento em Renda Fixa (Tesouro Direto)', 'Fundo de Ações'],
    'Valor (R$)': [100.00, 80.00, 30.00]
}

# Criar DataFrames
df_receitas = pd.DataFrame(receitas)
df_despesas_fixas = pd.DataFrame(despesas_fixas)
df_despesas_variaveis = pd.DataFrame(despesas_variaveis)
df_resumo_mensal = pd.DataFrame(resumo_mensal)
df_investimentos = pd.DataFrame(investimentos)

# Criar uma planilha Excel com várias abas
with pd.ExcelWriter('relatorio_financeiro.xlsx') as writer:
    df_receitas.to_excel(writer, sheet_name='Receitas', index=False)
    df_despesas_fixas.to_excel(writer, sheet_name='Despesas Fixas', index=False)
    df_despesas_variaveis.to_excel(writer, sheet_name='Despesas Variáveis', index=False)
    df_resumo_mensal.to_excel(writer, sheet_name='Resumo Mensal', index=False)
    df_investimentos.to_excel(writer, sheet_name='Investimentos', index=False)

print("Arquivo 'relatorio_financeiro.xlsx' criado com sucesso!")
# Out:
# Arquivo 'relatorio_financeiro.xlsx' criado com sucesso!
